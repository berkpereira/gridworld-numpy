# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# enable interactive plots
# %matplotlib widget

# %% [markdown]
# # Import and concatenate all 4D results data into a single dataframe

# %%
import os
import pickle

# Set the directory containing the CSV files
csv_dir = '../results/4d/results'

# Get a list of all CSV files in the directory
csv_files = [f for f in os.listdir(csv_dir) if f.endswith('.csv')]

# Concatenate all CSV files into a single dataframe
df_sim = pd.concat([pd.read_csv(os.path.join(csv_dir, f)) for f in csv_files])

# Load pickled train time dataframe
with open('../benchmark-policies/4d/wind_0,9_train_time.pkl', 'rb') as f:
    df_train = pickle.load(f)

# %%
df_sim.describe()
# Out:
#        dimension        MDP_ID    wind_param       l1_norm  no_solutions  \
# count  1260000.0  1.260000e+06  1.260000e+06  1.076672e+06  60000.000000
# mean         4.0  8.750000e+01  9.000000e-01  9.801927e-01      2.190583
# std          0.0  2.874458e+01  7.071071e-02  1.189574e+00      1.377834
# min          4.0  4.100000e+01  8.000000e-01  0.000000e+00      1.000000
# 25%          4.0  6.275000e+01  8.500000e-01  0.000000e+00      1.000000
# 50%          4.0  8.750000e+01  9.000000e-01  1.000000e+00      2.000000
# 75%          4.0  1.122500e+02  9.500000e-01  1.000000e+00      3.000000
# max          4.0  1.340000e+02  1.000000e+00  1.500000e+01     13.000000
#
#         solver_time
# count  60000.000000
# mean       0.720502
# std        0.843844
# min        0.116209
# 25%        0.217134
# 50%        0.421506
# 75%        0.882422
# max       14.135412

# %%
df_train
# Out:
#                      DP4        MC4
# 41_wind_0,9     1.767049   0.336776
# 42_wind_0,9     1.755515   0.339481
# 43_wind_0,9     1.678167   0.310009
# 44_wind_0,9     1.589444   0.298224
# 51_wind_0,9     4.588190   0.717241
# 52_wind_0,9     4.446107   0.685347
# 53_wind_0,9     4.438592   0.631205
# 54_wind_0,9     4.363804   0.615129
# 61_wind_0,9     9.874687   1.379644
# 62_wind_0,9     9.829982   1.320856
# 63_wind_0,9    10.044530   1.290582
# 64_wind_0,9    10.425386   1.165362
# 71_wind_0,9    19.004437   2.412036
# 72_wind_0,9    19.412263   2.258942
# 73_wind_0,9    20.124932   2.096448
# 74_wind_0,9    21.646552   1.899346
# 81_wind_0,9    32.902812   3.910143
# 82_wind_0,9    35.124759   3.653217
# 83_wind_0,9    37.248657   3.364997
# 84_wind_0,9    40.009291   3.170306
# 91_wind_0,9    53.713074   6.049222
# 92_wind_0,9    61.015123   5.864764
# 93_wind_0,9    66.094068   5.270529
# 94_wind_0,9    72.618230   4.699167
# 101_wind_0,9   83.100435   8.892965
# 102_wind_0,9   94.622927   8.390335
# 103_wind_0,9  106.152638   7.337284
# 104_wind_0,9  120.302226   6.974558
# 111_wind_0,9  124.603633  12.818283
# 112_wind_0,9  147.701230  12.046896
# 113_wind_0,9  167.240403  10.720999
# 114_wind_0,9  189.212245   8.738748
# 121_wind_0,9  178.254585  18.233251
# 122_wind_0,9  217.945429  17.413233
# 123_wind_0,9  249.410795  15.674342
# 124_wind_0,9  284.758680  11.702253
# 131_wind_0,9  245.523309  23.782790
# 132_wind_0,9  309.087783  23.368377
# 133_wind_0,9  365.195269  20.653439
# 134_wind_0,9  428.045425  18.192459

# %%
# Create new columns
df_train['grid_size'] = df_train.index.str.extract(r'^(\d{1,2})\d{1}', expand=False).astype(int)
df_train['obstacle_density'] = df_train.index.str.extract(r'^\d{1,2}(\d{1})', expand=False).astype(int)

# Remove the original index
df_train.reset_index(drop=True, inplace=True)

# Print the result
df_train
# Out:
#            DP4        MC4  grid_size  obstacle_density
# 0     1.767049   0.336776          4                 1
# 1     1.755515   0.339481          4                 2
# 2     1.678167   0.310009          4                 3
# 3     1.589444   0.298224          4                 4
# 4     4.588190   0.717241          5                 1
# 5     4.446107   0.685347          5                 2
# 6     4.438592   0.631205          5                 3
# 7     4.363804   0.615129          5                 4
# 8     9.874687   1.379644          6                 1
# 9     9.829982   1.320856          6                 2
# 10   10.044530   1.290582          6                 3
# 11   10.425386   1.165362          6                 4
# 12   19.004437   2.412036          7                 1
# 13   19.412263   2.258942          7                 2
# 14   20.124932   2.096448          7                 3
# 15   21.646552   1.899346          7                 4
# 16   32.902812   3.910143          8                 1
# 17   35.124759   3.653217          8                 2
# 18   37.248657   3.364997          8                 3
# 19   40.009291   3.170306          8                 4
# 20   53.713074   6.049222          9                 1
# 21   61.015123   5.864764          9                 2
# 22   66.094068   5.270529          9                 3
# 23   72.618230   4.699167          9                 4
# 24   83.100435   8.892965         10                 1
# 25   94.622927   8.390335         10                 2
# 26  106.152638   7.337284         10                 3
# 27  120.302226   6.974558         10                 4
# 28  124.603633  12.818283         11                 1
# 29  147.701230  12.046896         11                 2
# 30  167.240403  10.720999         11                 3
# 31  189.212245   8.738748         11                 4
# 32  178.254585  18.233251         12                 1
# 33  217.945429  17.413233         12                 2
# 34  249.410795  15.674342         12                 3
# 35  284.758680  11.702253         12                 4
# 36  245.523309  23.782790         13                 1
# 37  309.087783  23.368377         13                 2
# 38  365.195269  20.653439         13                 3
# 39  428.045425  18.192459         13                 4

# %%
fig = plt.figure()

# First subplot
ax1 = fig.add_subplot(121, projection='3d')
ax1.plot_trisurf(df_train['grid_size'], df_train['obstacle_density'], df_train['DP4'], cmap='viridis')
ax1.set_xlabel('Grid Size')
ax1.set_ylabel('Obstacle Density')
ax1.set_zlabel('DP4')

"""
# Second subplot
ax2 = fig.add_subplot(122, projection='3d')
ax2.plot_trisurf(df_train['grid_size'], df_train['obstacle_density'], df_train['MC4'], cmap='viridis')
ax2.set_xlabel('Grid Size')
ax2.set_ylabel('Obstacle Density')
ax2.set_zlabel('MC4')
"""

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
